# %% [markdown]
# # COSC 118: Introductory Scientific Programming

# %% [markdown]
# Instructor: Dr. Shuangquan (Peter) Wang
#
# Email: spwang@salisbury.edu
#
# Department of Computer Science, Salisbury University

# %% [markdown]
# # Module 1_Python Basics
#
# ## 4. Branching

# %% [markdown]
# **Contents of this note refer to 1) the teaching materials at Department of Computer Science, William & Mary; 2) the textbook "Python crash course - a hands-on project-based introduction to programming"; 3) Python toturial: https://docs.python.org/3/tutorial/**

# %% [markdown]
# **<font color=red>All rights reserved. Dissemination or sale of any part of this note is NOT permitted.</font>**

# %% [markdown]
# ## Read textbook
#
# - Python Crash Course: Chapter 5 if statements
# - Starting out with Python: Chapter 3 Decision structures and boolean logic

# %% [markdown]
# #  if statements

# %% [markdown]
# Some examples of conditionals:
#
# &nbsp;
#
# 1. if it is sunny, I will play tennis
#
# &nbsp;
#
# 2.  if my answer of this question is right, I will do the next question;
#
# &emsp;&emsp; otherwise, I will do this question again.
#
# &nbsp;
#
# 3. The children whose age is less than 4 (age < 4), please go to room 1;
#
# &emsp;&emsp; the children whose age satisfies 4 <= age < 8, please go to room 2;
#
# &emsp;&emsp; all the remaining children please go to room 3.
#
# &nbsp;

# %% [markdown]
# ## 1. Simple "if statement"

# %%
# Syntax:
if conditional_test:
    code block

# %% [markdown]
# **Pay attention:**
#
# 1. The conditional_test could be comparison, chain comparison, membership operation, identity operation, boolean variable/value or boolen operation
#
# 2. If conditional_test is **True**, execute the code block; otherwise, do nothing;
#
# 3. Do NOT forget the **colon** at the end of **if** line;
#
# 4. As in the function, we use **indentation** to indicate the code block (lines) included in this if statement;

# %% [markdown]
# **Example:**
#
# Use a Python editor to write a program and test in command line.
#
# Define a function named **isEven()**, and use "**if statement**" in this function to:
#
# if the input ingeter is an even number, return **True**; otherwise return **False**.

# %% [markdown]
# ## 2. if-else statement

# %%
# Syntax
if conditional_test:
    code block 1
else:
    code block 2

# %% [markdown]
# 1. Similar syntax with that of "simple if statement". **else** means otherwise.
#
# 2. When conditional_test is **True**, execute code block 1 (then finished); otherwise, execute code block 2 (then finished).
#
# 3. Either code block 1 or code block 2 will be executed.
#
# 4. The **if** line and the **else** line are in the same indentation level.

# %% [markdown]
# **Example:**
#
# Use a Python editor to write a program and test in command line.
#
# Define a function named **isEven()**, and use "**if-else statement**" in this function to:
#
# if the input integer is an even number, return **True**; otherwise return **False**.

# %% [markdown]
# **Practice:**
#
# Use "if-else statement" to:
#
# Ask a user to input an interger to represent the **Month**, if the input is between 1 and 12 (include 1 and 12), print "Valid"; otherise print "Invalid".

# %% [markdown]
# ## 3. if-elif-else statement

# %%
# Syntax
if conditional_test_1:
    code block 1
elif conditional_test_2:
    code block 2
else:
    code block 3

# %% [markdown]
# 1. Check conditional_test_1, if it is **True**, execute code block 1 and finish; otherwise go to the **elif** line. Check conditional_test_2, if it is **True**, execute code block 2 and finish; otherwise execute code block 3.
#
# 2. You can have multiple **elif** statements here
#
# 3. Only one and at most one code block will be executed.
#
# 4. **else** line and code block 3 part is optional. However, if there is no **else** line, maybe NO code block will be executed.

# %% [markdown]
# **Example:**
#
# Ask a user to input his/her age, then print the park ticket price.
#
# Park ticket price:
#
# - age < 2: $0
#
# - 2 <= age <5: $2
#
# - 5 <= age < 10: $4
#
# - 10 <= age: $5

# %% [markdown]
# **Practice:**
#
# Write a function to do the following:
#
# - if the input is 'a', print('Apple')
#
# - if the input is 'b', print('Banana')
#
# - if the input is 'g', print('Grape')
#
# - otherwise, print 'We do not provide this fruit'.
#
# Then, ask a user to input a low-case character, call this function to show the result.

# %% [markdown]
# **Practice:**
#
# if A:
#
#     code block 1
#
# How many code block will be executed here?

# %% [markdown]
# #

# %% [markdown]
# <div class="voila">
# 0 or 1 code block will be executed.
# </div>

# %% [markdown]
# **Practice:**
#
# if A:
#
#     code block 1
#
# else:
#
#     code block 2
#
# How many code block will be executed here?

# %% [markdown]
# #

# %% [markdown]
# <div class="voila">
# 1 code block will be executed.
# </div>

# %% [markdown]
# **Practice:**
#
# if A:
#
#     code block 1
#
# if B:
#
#     code block 2
#
# How many code block will be executed here?

# %% [markdown]
# #

# %% [markdown]
# <div class="voila">
# 0 or 1 or 2 code block will be executed.
# </div>

# %% [markdown]
# **Practice:**
#
# if A:
#
#     code block 1
#
# elif B:
#
#     code block 2
#
# elif C:
#
#     code block 3
#
# How many code block will be executed here?

# %% [markdown]
# #

# %% [markdown]
# <div class="voila">
# 0 or 1 code block will be executed.
# </div>

# %% [markdown]
# **Practice:**
#
# if A:
#
#     code block 1
#
# elif B:
#
#     code block 2
#
# else:
#
#     code block 3
#
# How many code block will be executed here?

# %% [markdown]
# #

# %% [markdown]
# <div class="voila">
# 1 code block will be executed.
# </div>

# %% [markdown]
# ## Review of boolean expression

# %%
a        b        a and b        a or b        not a
T        T           T              T           F
T        F           F              T           F
F        T           F              T           T
F        F           F              F           T

# %%
if conditioal_test_1 or coditional_test_2:
    code block 1

# If conditioal_test_1 is True, I don't have to check the coditional_test_2

# %%
if conditioal_test_1 and coditional_test_2:
    code 1

# I need to check both conditioal_test_1 and conditioal_test_2

# %% [markdown]
# **Question:**
#
# If the conditioal_tests in if and elif lines have overlap, what will happen?

# %% [markdown]
# ## Python indentation
#
# -- Refer to https://www.programiz.com/python-programming/statement-indentation-comments
#
# 1. Python uses indentation to define a block of code.
#
# 2. A code block (body of a function, loop etc.) starts with indentation and ends with the **first unindented line**.
#
# 3. The enforcement of indentation in Python makes the code look neat and clean.

# %% [markdown]
# **For example:**

# %%
def outer():
    name = 'outer function'
    print(name)
    
    def inner_1():
        name = 'inner function 1'
        print(name)
    inner_1()
    print(name)
    
    def inner_2():
        name = 'inner function 2'
        print(name)
    inner_2()
    print(name)

name = 'main function'
print(name)
outer()
print(name)

# %% [markdown]
# **Question:**
#
# 1. Which lines are included in the body of the outer function?
# 2. Which lines are included in the body of the inner_1 function?
# 3. Which lines are included in the body of the inner_2 function?

# %%
from IPython.display import Image
Image(filename='function_indentation.png',width=300)

# %% [markdown]
# **Example:**

# %%
if condtion_0:
    if condition_1:
        if condition_1_1:
            code block_1_1_1
        else:
            code block_1_1_2
    else:
        if condition_1_2:
            code block_1_2_1
        else:
            code block_1_2_2
else:
    if condition_2:
        if condition_2_1:
            code block_2_1_1
        else:
            code block_2_1_2
    else:
        if condition_2_2:
            code block_2_2_1
        else:
            code block_2_2_2

# %% [markdown]
# **Question:**
#
# 1. Which lines are included in the code block (and will be executed) when "condition_0:" is True?
#
# 2. Which lines are included in the code block (and will be executed) when "condition_0:" is not True?
#
# 3. Which lines are included in the code block (and will be executed) when "condition_1:" is True?
#
# 4. Which lines are included in the code block (and will be executed) when "condition_2_1:" is not True?

# %% [markdown]
# ## Transform if-else statement into Decision Tree model

# %%
from IPython.display import Image
Image(filename='If_DT_Tree.png',width=700)

# %% [markdown]
# **More examples about Decision Tree**

# %%
from IPython.display import Image
Image(filename='DecisionTreeExample2.jpeg',width=500)

# This figure is from: https://dev.to/nexttech/classification-and-regression-analysis-with-decision-trees-jgp

# %% [markdown]
# **Practice:**
#
# Use a Python editor to write the code and test the code in command line:
#
# 1. Write a function, the input is numerical scores, return the corresponding grade letters
#
# -- 97 <= score <= 100: A+
#
# -- 93 <= score < 97: A
#
# -- 90 <= score < 93: A-
#
# 2. In the main program, ask user to input a score (between 90 and 100);
#
# 3. call the function to get the grade letter and print it to the screen

# %% [markdown]
# Let's have a look on this implementation (grad_wrong.py)
